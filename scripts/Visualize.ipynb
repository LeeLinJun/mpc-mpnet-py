# %%
from visualization import Visualizer, CartpoleVisualizer

# %%
import sys
sys.path.append('..')
from mpnet.sst_envs.utils import load_data, get_obs
data = load_data('cartpole_obs', 0, 1802 )
obs = get_obs('cartpole_obs', 'obs')[0]
import numpy as np

# %%
obs
# Out:
# array([[-11.76184125,  -2.75      ],
#        [  2.07518013,  -2.75      ],
#        [ 16.75439302,   3.75      ],
#        [  8.07880454,   3.75      ],
#        [ -9.24174079,   3.75      ],
#        [ 15.30796802,  -2.75      ],
#        [  0.64608927,   3.75      ]])

# %%
viz = CartpoleVisualizer(obs=obs)
waypoints = np.array([
    [-21.79909121,   0.         ,  1.10758313  , 0.        ],
    [-21.24461401,   3.05017146,   0.83551358,  -1.45632234],
    [-16.93218474,  10.88846448,  -0.33456441,  -2.        ],
    [ -9.97612207,  19.5391628 ,  -1.23301631,  -1.94796085],
    [ -0.22167842,  27.25124927,  -1.83545191,  -0.6759323 ],
    [ 13.15001828,  17.29047459,  -2.06497128,  -0.21596034],
    [ 21.47158484,  10.42390895,  -2.03360013 ,  0.33560039]])
viz.plot(waypoints, goal=waypoints[-1], ref_path=data['path'])

# %%
viz.obs_color
# Out:
# 'black'
